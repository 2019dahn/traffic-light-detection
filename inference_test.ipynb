# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/Othercomputers/'내 MacBook Air'/project
# %cd yolov5
# Out:
# /content/drive/Othercomputers/내 MacBook Air/project
# /content/drive/Othercomputers/내 MacBook Air/project/yolov5

# %%
# 처음 1회만
# !pip install -r requirements.txt  # install
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00
# ...

# %%
# !python3 detect.py --weights traffic-int8.tflite --source data/images/sample_img_1.jpeg --data data/trafficlight.yaml
# Out:
# detect: weights=['traffic-int8.tflite'], source=data/images/sample_img_1.jpeg, data=data/trafficlight.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/content/drive/Othercomputers/내': No such file or directory
# YOLOv5 🚀 2023-8-30 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Loading traffic-int8.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# prediction.shape: torch.Size([1, 25200, 6])
# bs value: 1
# nc value: 1
# xc.shape: torch.Size([1, 25200])
# x.shape: torch.Size([36, 6])
# xi: 0
# xc.shape: torch.Size([1, 25200])
# number of boxes: 36
# ...
